# %% [markdown]
# # Installing the right packages

# %% [markdown]
# Execute the cell below to install the required pip packages

# %%
! pip install -q -r requirements.txt

# %% [markdown]
# ## Streamlit this app

# %% [markdown]
# * right-click on `app.py` in the left-hand navigation pane
# * select **Streamlit this file**
# * wait for a new tab to open

# %% [markdown]
# ![image.png](attachment:6cf7f930-da5f-468d-a90d-d69bd95b032b.png)
